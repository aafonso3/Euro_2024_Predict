# %%
import pandas as pd
from string import ascii_uppercase as alphabet
import pickle
from bs4 import BeautifulSoup
import requests

from scipy.stats import poisson

# %%
all_tables = pd.read_html('https://en.wikipedia.org/wiki/UEFA_Euro_2024')

# %%
all_tables[20]
all_tables[27]
all_tables[55]
# Out:
#    Pos         Teamvte  Pld  W  D  L  GF  GA  GD   Pts  \
# 0    1        Portugal    3  2  0  1   5   3  +2  6[a]
# 1    2          Turkey    3  2  0  1   5   5   0  6[a]
# 2    3         Georgia    3  1  1  1   4   4   0     4
# 3    4  Czech Republic    3  0  1  2   3   5  −2     1
#
#                Qualification
# 0  Advance to knockout stage
# 1  Advance to knockout stage
# 2  Advance to knockout stage
# 3                        NaN

# %%
all_tables = pd.read_html('https://en.wikipedia.org/wiki/UEFA_Euro_2024')
dict_table = {}
for letter, i in zip(alphabet, range(20, 62, 7)):
  df = all_tables[i]
  df.rename(columns = {df.columns[1]: 'Team'}, inplace=True)
  df.pop('Qualification')
  dict_table[f'Group {letter}'] = df
  print(letter, i)
# Out:
# A 20
# B 27
# C 34
# D 41
# E 48
# F 55

# %%
dict_table['Group A']
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1  Germany (H)    3  2  1  0   8   2  +6    7
# 1    2  Switzerland    3  1  2  0   5   3  +2    5
# 2    3      Hungary    3  1  0  2   2   5  −3    3
# 3    4     Scotland    3  0  1  2   2   7  −5    1

# %%
with open('dict_table', 'wb') as output:
  pickle.dump(dict_table, output)

# %%
years = [2020, 2016, 2012, 2008, 2004, 2000, 1996, 1992, 1988, 1984, 1980, 1976, 1972, 1968, 1964, 1960]

# %%
def get_matches(year):
  web = f'https://en.wikipedia.org/wiki/UEFA_Euro_{year}'
  response = requests.get(web)
  content = response.text
  soup = BeautifulSoup(content, 'lxml')
  matches = soup.find_all('div',  class_='footballbox')
  home = []
  away = []
  score = []
  for match in matches:
    home.append(match.find('th', class_='fhome').get_text())
    away.append(match.find('th', class_='faway').get_text())
    score.append(match.find('th', class_='fscore').get_text())
  dict_football = {'home': home, 'away': away, 'score': score}
  df_football = pd.DataFrame(dict_football)
  df_football['year'] = year
  return df_football

# %%
euro_2024_game = get_matches(2024)

# %%
euro_2024_game = pd.read_csv('euro_2024_game.csv')

# %%
euro_2024_game
# Out:
#                home             away score  year
# 0          Germany          Scotland   5–1  2024
# 1          Hungary       Switzerland   1–3  2024
# 2          Germany           Hungary   2–0  2024
# 3         Scotland       Switzerland   1–1  2024
# 4      Switzerland           Germany   1–1  2024
# 5         Scotland           Hungary   0–1  2024
# 6            Spain           Croatia   3–0  2024
# 7            Italy           Albania   2–1  2024
# 8          Croatia           Albania   2–2  2024
# 9            Spain             Italy   1–0  2024
# 10         Albania             Spain   0–1  2024
# 11         Croatia             Italy   1–1  2024
# 12        Slovenia           Denmark   1–1  2024
# 13          Serbia           England   0–1  2024
# 14        Slovenia            Serbia   1–1  2024
# 15         Denmark           England   1–1  2024
# 16         England          Slovenia   0–0  2024
# 17         Denmark            Serbia   0–0  2024
# 18          Poland       Netherlands   1–2  2024
# 19         Austria            France   0–1  2024
# 20          Poland           Austria   1–3  2024
# 21     Netherlands            France   0–0  2024
# 22     Netherlands           Austria   2–3  2024
# 23          France            Poland   1–1  2024
# 24         Romania           Ukraine   3–0  2024
# 25         Belgium          Slovakia   0–1  2024
# 26        Slovakia           Ukraine   1–2  2024
# 27         Belgium           Romania   2–0  2024
# 28        Slovakia           Romania   1–1  2024
# 29         Ukraine           Belgium   0–0  2024
# 30          Turkey           Georgia   3–1  2024
# 31        Portugal    Czech Republic   2–1  2024
# 32         Georgia    Czech Republic   1–1  2024
# 33          Turkey          Portugal   0–3  2024
# 34         Georgia          Portugal   2–0  2024
# 35  Czech Republic            Turkey   1–2  2024

# %%
euro_all = [get_matches(year) for year in years]
df_euro_all = pd.concat(euro_all, ignore_index=True)
df_euro_all.to_csv('df_euro_all.csv', index=False)

# %%
df_fixture = get_matches(2024)
df_fixture.to_csv('df_euro_fixture.csv', index=False)

# %%
df_fixture['home'] = df_fixture['home'].str.strip()
df_fixture['away'] = df_fixture['away'].str.strip()
euro_2024_game['home'] = euro_2024_game['home'].str.strip()
euro_2024_game['away'] = euro_2024_game['away'].str.strip()

# %%
df_fixture
# Out:
#                home             away     score  year
# 0           Germany         Scotland       5–1  2024
# 1           Hungary      Switzerland       1–3  2024
# 2           Germany          Hungary       2–0  2024
# 3          Scotland      Switzerland       1–1  2024
# 4       Switzerland          Germany       1–1  2024
# 5          Scotland          Hungary       0–1  2024
# 6             Spain          Croatia       3–0  2024
# 7             Italy          Albania       2–1  2024
# 8           Croatia          Albania       2–2  2024
# 9             Spain            Italy       1–0  2024
# 10          Albania            Spain       0–1  2024
# 11          Croatia            Italy       1–1  2024
# 12         Slovenia          Denmark       1–1  2024
# 13           Serbia          England       0–1  2024
# 14         Slovenia           Serbia       1–1  2024
# 15          Denmark          England       1–1  2024
# 16          England         Slovenia       0–0  2024
# 17          Denmark           Serbia       0–0  2024
# 18           Poland      Netherlands       1–2  2024
# 19          Austria           France       0–1  2024
# 20           Poland          Austria       1–3  2024
# 21      Netherlands           France       0–0  2024
# 22      Netherlands          Austria       2–3  2024
# 23           France           Poland       1–1  2024
# 24          Romania          Ukraine       3–0  2024
# 25          Belgium         Slovakia       0–1  2024
# 26         Slovakia          Ukraine       1–2  2024
# 27          Belgium          Romania       2–0  2024
# 28         Slovakia          Romania       1–1  2024
# 29          Ukraine          Belgium       0–0  2024
# 30           Turkey          Georgia       3–1  2024
# 31         Portugal   Czech Republic       2–1  2024
# 32          Georgia   Czech Republic       1–1  2024
# 33           Turkey         Portugal       0–3  2024
# 34          Georgia         Portugal       2–0  2024
# 35   Czech Republic           Turkey       1–2  2024
# 36      Switzerland            Italy  Match 38  2024
# 37          Germany          Denmark  Match 37  2024
# 38          England         Slovakia  Match 40  2024
# 39            Spain          Georgia  Match 39  2024
# 40           France          Belgium  Match 42  2024
# 41         Portugal         Slovenia  Match 41  2024
# 42          Romania      Netherlands  Match 43  2024
# 43          Austria           Turkey  Match 44  2024
# 44  Winner Match 39  Winner Match 37  Match 45  2024
# 45  Winner Match 41  Winner Match 42  Match 46  2024
# 46  Winner Match 40  Winner Match 38  Match 48  2024
# 47  Winner Match 43  Winner Match 44  Match 47  2024
# 48  Winner Match 45  Winner Match 46  Match 49  2024
# 49  Winner Match 47  Winner Match 48  Match 50  2024
# 50  Winner Match 49  Winner Match 50  Match 51  2024

# %%
df_euro_all.sort_values('year', inplace=True)
df_euro_all
# Out:
#                 home           away         score  year
# 336    Soviet Union      Yugoslavia  2–1 (a.e.t.)  1960
# 333          France      Yugoslavia           4–5  1960
# 335  Czechoslovakia          France           2–0  1960
# 334  Czechoslovakia    Soviet Union           0–3  1960
# 332           Spain    Soviet Union           2–1  1964
# ..               ...            ...           ...   ...
# 29           Sweden          Poland           3–2  2020
# 28         Slovakia           Spain           0–5  2020
# 27            Spain          Poland           1–1  2020
# 25            Spain          Sweden           0–0  2020
# 0            Turkey           Italy           0–3  2020
#
# [337 rows x 4 columns]

# %%
df_euro_all['score'] = df_euro_all['score'].str.replace('[^\d–]', '', regex = True)
euro_2024_game['score'] = euro_2024_game['score'].str.replace('[^\d–]', '', regex = True)

# %%
df_euro_all['home'] = df_euro_all['home'].str.strip()
df_euro_all['away'] = df_euro_all['away'].str.strip()

# %%
df_euro_all
# Out:
#                home          away score  year
# 336    Soviet Union    Yugoslavia   2–1  1960
# 333          France    Yugoslavia   4–5  1960
# 335  Czechoslovakia        France   2–0  1960
# 334  Czechoslovakia  Soviet Union   0–3  1960
# 332           Spain  Soviet Union   2–1  1964
# ..              ...           ...   ...   ...
# 29           Sweden        Poland   3–2  2020
# 28         Slovakia         Spain   0–5  2020
# 27            Spain        Poland   1–1  2020
# 25            Spain        Sweden   0–0  2020
# 0            Turkey         Italy   0–3  2020
#
# [337 rows x 4 columns]

# %%
euro_2024_game
# Out:
#               home            away score  year
# 0          Germany        Scotland   5–1  2024
# 1          Hungary     Switzerland   1–3  2024
# 2          Germany         Hungary   2–0  2024
# 3         Scotland     Switzerland   1–1  2024
# 4      Switzerland         Germany   1–1  2024
# 5         Scotland         Hungary   0–1  2024
# 6            Spain         Croatia   3–0  2024
# 7            Italy         Albania   2–1  2024
# 8          Croatia         Albania   2–2  2024
# 9            Spain           Italy   1–0  2024
# 10         Albania           Spain   0–1  2024
# 11         Croatia           Italy   1–1  2024
# 12        Slovenia         Denmark   1–1  2024
# 13          Serbia         England   0–1  2024
# 14        Slovenia          Serbia   1–1  2024
# 15         Denmark         England   1–1  2024
# 16         England        Slovenia   0–0  2024
# 17         Denmark          Serbia   0–0  2024
# 18          Poland     Netherlands   1–2  2024
# 19         Austria          France   0–1  2024
# 20          Poland         Austria   1–3  2024
# 21     Netherlands          France   0–0  2024
# 22     Netherlands         Austria   2–3  2024
# 23          France          Poland   1–1  2024
# 24         Romania         Ukraine   3–0  2024
# 25         Belgium        Slovakia   0–1  2024
# 26        Slovakia         Ukraine   1–2  2024
# 27         Belgium         Romania   2–0  2024
# 28        Slovakia         Romania   1–1  2024
# 29         Ukraine         Belgium   0–0  2024
# 30          Turkey         Georgia   3–1  2024
# 31        Portugal  Czech Republic   2–1  2024
# 32         Georgia  Czech Republic   1–1  2024
# 33          Turkey        Portugal   0–3  2024
# 34         Georgia        Portugal   2–0  2024
# 35  Czech Republic          Turkey   1–2  2024

# %%
df_euro_all[['HomeGoals', 'AwayGoals']] =  df_euro_all['score'].str.split('–', expand=True)
euro_2024_game[['HomeGoals', 'AwayGoals']] =  euro_2024_game['score'].str.split('–', expand=True)

# %%
df_euro_all.rename(columns = {'home': 'HomeTeam', 'away': 'AwayTeam', 'year':'Year'}, inplace=True)
euro_2024_game.rename(columns = {'home': 'HomeTeam', 'away': 'AwayTeam', 'year':'Year'}, inplace=True)

# %%
df_euro_all.dtypes
# Out:
# HomeTeam     object
# AwayTeam     object
# score        object
# Year          int64
# HomeGoals    object
# AwayGoals    object
# dtype: object

# %%
euro_2024_game.dtypes
# Out:
# HomeTeam     object
# AwayTeam     object
# score        object
# Year          int64
# HomeGoals    object
# AwayGoals    object
# dtype: object

# %%
df_euro_all['HomeGoals'] = df_euro_all['HomeGoals'].astype(int)
df_euro_all['AwayGoals'] = df_euro_all['AwayGoals'].astype(int)
euro_2024_game['HomeGoals'] = euro_2024_game['HomeGoals'].astype(int)
euro_2024_game['AwayGoals'] = euro_2024_game['AwayGoals'].astype(int)

# %%
df_euro_all.dtypes
# Out:
# HomeTeam     object
# AwayTeam     object
# score        object
# Year          int64
# HomeGoals     int64
# AwayGoals     int64
# dtype: object

# %%
euro_2024_game.dtypes
# Out:
# HomeTeam     object
# AwayTeam     object
# score        object
# Year          int64
# HomeGoals     int64
# AwayGoals     int64
# dtype: object

# %%
df_euro_all['TotalGoals'] = df_euro_all['HomeGoals'] + df_euro_all['AwayGoals']

# %%
euro_2024_game['TotalGoals'] = euro_2024_game['HomeGoals'] + euro_2024_game['AwayGoals']

# %%
df_euro_all = pd.merge(df_euro_all, euro_2024_game, how='outer')

# %%
euro_2024_game
# Out:
#           HomeTeam        AwayTeam score  Year  HomeGoals  AwayGoals  \
# 0          Germany        Scotland   5–1  2024          5          1
# 1          Hungary     Switzerland   1–3  2024          1          3
# 2          Germany         Hungary   2–0  2024          2          0
# 3         Scotland     Switzerland   1–1  2024          1          1
# 4      Switzerland         Germany   1–1  2024          1          1
# 5         Scotland         Hungary   0–1  2024          0          1
# 6            Spain         Croatia   3–0  2024          3          0
# 7            Italy         Albania   2–1  2024          2          1
# 8          Croatia         Albania   2–2  2024          2          2
# 9            Spain           Italy   1–0  2024          1          0
# 10         Albania           Spain   0–1  2024          0          1
# 11         Croatia           Italy   1–1  2024          1          1
# 12        Slovenia         Denmark   1–1  2024          1          1
# 13          Serbia         England   0–1  2024          0          1
# 14        Slovenia          Serbia   1–1  2024          1          1
# 15         Denmark         England   1–1  2024          1          1
# 16         England        Slovenia   0–0  2024          0          0
# 17         Denmark          Serbia   0–0  2024          0          0
# 18          Poland     Netherlands   1–2  2024          1          2
# 19         Austria          France   0–1  2024          0          1
# 20          Poland         Austria   1–3  2024          1          3
# 21     Netherlands          France   0–0  2024          0          0
# 22     Netherlands         Austria   2–3  2024          2          3
# 23          France          Poland   1–1  2024          1          1
# 24         Romania         Ukraine   3–0  2024          3          0
# 25         Belgium        Slovakia   0–1  2024          0          1
# 26        Slovakia         Ukraine   1–2  2024          1          2
# 27         Belgium         Romania   2–0  2024          2          0
# 28        Slovakia         Romania   1–1  2024          1          1
# 29         Ukraine         Belgium   0–0  2024          0          0
# 30          Turkey         Georgia   3–1  2024          3          1
# 31        Portugal  Czech Republic   2–1  2024          2          1
# 32         Georgia  Czech Republic   1–1  2024          1          1
# 33          Turkey        Portugal   0–3  2024          0          3
# 34         Georgia        Portugal   2–0  2024          2          0
# 35  Czech Republic          Turkey   1–2  2024          1          2
#
#     TotalGoals
# 0            6
# 1            4
# 2            2
# 3            2
# 4            2
# 5            1
# 6            3
# 7            3
# 8            4
# 9            1
# 10           1
# 11           2
# 12           2
# 13           1
# 14           2
# 15           2
# 16           0
# 17           0
# 18           3
# 19           1
# 20           4
# 21           0
# 22           5
# 23           2
# 24           3
# 25           1
# 26           3
# 27           2
# 28           2
# 29           0
# 30           4
# 31           3
# 32           2
# 33           3
# 34           2
# 35           3

# %%
df_euro_all
# Out:
#            HomeTeam        AwayTeam score  Year  HomeGoals  AwayGoals  \
# 0      Soviet Union      Yugoslavia   2–1  1960          2          1
# 1            France      Yugoslavia   4–5  1960          4          5
# 2    Czechoslovakia          France   2–0  1960          2          0
# 3    Czechoslovakia    Soviet Union   0–3  1960          0          3
# 4             Spain    Soviet Union   2–1  1964          2          1
# ..              ...             ...   ...   ...        ...        ...
# 368        Portugal  Czech Republic   2–1  2024          2          1
# 369         Georgia  Czech Republic   1–1  2024          1          1
# 370          Turkey        Portugal   0–3  2024          0          3
# 371         Georgia        Portugal   2–0  2024          2          0
# 372  Czech Republic          Turkey   1–2  2024          1          2
#
#      TotalGoals
# 0             3
# 1             9
# 2             2
# 3             3
# 4             3
# ..          ...
# 368           3
# 369           2
# 370           3
# 371           2
# 372           3
#
# [373 rows x 7 columns]

# %%
dict_table = pickle.load(open('dict_table', 'rb'))

# %%
df_home = df_euro_all[['HomeTeam','HomeGoals', 'AwayGoals']]
df_away = df_euro_all[['AwayTeam','HomeGoals', 'AwayGoals']]

# %%
df_home = df_home.rename(columns = {'HomeTeam': 'Team', 'HomeGoals': 'GoalsScored', 'AwayGoals': 'GoalsConcided'})
df_away = df_away.rename(columns = {'AwayTeam': 'Team', 'AwayGoals': 'GoalsScored', 'HomeGoals': 'GoalsConcided'})

# %%
df_team_strenght = pd.concat([df_home, df_away], ignore_index=True).groupby('Team').mean()
df_team_strenght
# Out:
#                      GoalsScored  GoalsConcided
# Team
# Albania                 0.666667       1.333333
# Austria                 1.000000       1.230769
# Belgium                 1.320000       1.160000
# Bulgaria                0.666667       2.166667
# CIS                     0.333333       1.333333
# Croatia                 1.320000       1.360000
# Czech Republic          1.218750       1.312500
# Czechoslovakia          1.500000       1.250000
# Denmark                 1.222222       1.444444
# England                 1.292683       0.926829
# FR Yugoslavia           2.000000       3.250000
# Finland                 0.333333       1.000000
# France                  1.543478       1.108696
# Georgia                 1.333333       1.333333
# Germany                 1.487805       1.073171
# Greece                  0.875000       1.250000
# Hungary                 1.142857       1.785714
# Iceland                 1.600000       1.800000
# Italy                   1.145833       0.708333
# Latvia                  0.333333       1.666667
# Netherlands             1.642857       1.071429
# North Macedonia         0.666667       2.666667
# Northern Ireland        0.500000       0.750000
# Norway                  0.333333       0.333333
# Poland                  0.823529       1.235294
# Portugal                1.452381       0.976190
# Republic of Ireland     0.600000       1.700000
# Romania                 0.736842       1.263158
# Russia                  1.100000       1.800000
# Scotland                0.583333       1.416667
# Serbia                  0.333333       0.666667
# Slovakia                0.800000       1.600000
# Slovenia                1.000000       1.166667
# Soviet Union            1.307692       0.923077
# Spain                   1.489796       0.857143
# Sweden                  1.250000       1.166667
# Switzerland             1.000000       1.285714
# Turkey                  0.904762       1.666667
# Ukraine                 0.714286       1.642857
# Wales                   1.300000       1.200000
# West Germany            1.666667       0.866667
# Yugoslavia              1.400000       2.600000

# %%
def predict_points(home, away):
    if home in df_team_strenght.index and away in df_team_strenght.index:
        # goals_scored * goals_conceded
        lamb_home = df_team_strenght.at[home,'GoalsScored'] * df_team_strenght.at[away,'GoalsConcided']
        lamb_away = df_team_strenght.at[away,'GoalsScored'] * df_team_strenght.at[home,'GoalsConcided']
        prob_home, prob_away, prob_draw = 0, 0, 0
        for x in range(0,11): #number of goals home team
            for y in range(0, 11): #number of goals away team
                p = poisson.pmf(x, lamb_home) * poisson.pmf(y, lamb_away)
                if x == y:
                    prob_draw += p
                elif x > y:
                    prob_home += p
                else:
                    prob_away += p

        points_home = 3 * prob_home + prob_draw
        points_away = 3 * prob_away + prob_draw
        return (points_home, points_away)
    else:
        return (0, 0)

# %%
#predict_points('Portugal', 'Turkey')
#predict_points('Turkey','Czech Republic' )
predict_points('Portugal', 'Slovenia')
# Out:
# (1.8679513090032727, 0.891356118180694)

# %%
df_fixture_group = df_fixture[:36].copy()
df_fixture_knoutout = df_fixture[36:44].copy()
df_fixture_quarter = df_fixture[44:48].copy()
df_fixture_semi = df_fixture[48:50].copy()
df_fixture_final = df_fixture[50:51].copy()

# %%
df_fixture_knoutout
# Out:
#            home         away     score  year
# 36  Switzerland        Italy  Match 38  2024
# 37      Germany      Denmark  Match 37  2024
# 38      England     Slovakia  Match 40  2024
# 39        Spain      Georgia  Match 39  2024
# 40       France      Belgium  Match 42  2024
# 41     Portugal     Slovenia  Match 41  2024
# 42      Romania  Netherlands  Match 43  2024
# 43      Austria       Turkey  Match 44  2024

# %%
def get_winner(df_fixture_updated):
    for index, row in df_fixture_updated.iterrows():
        home, away = row['home'], row['away']
        points_home, points_away = predict_points(home, away)
        if points_home > points_away:
            winner = home
        else:
            winner = away
        df_fixture_updated.loc[index, 'winner'] = winner
    return df_fixture_updated

# %%
get_winner(df_fixture_knoutout)
# Out:
#            home         away     score  year       winner
# 36  Switzerland        Italy  Match 38  2024        Italy
# 37      Germany      Denmark  Match 37  2024      Germany
# 38      England     Slovakia  Match 40  2024      England
# 39        Spain      Georgia  Match 39  2024        Spain
# 40       France      Belgium  Match 42  2024       France
# 41     Portugal     Slovenia  Match 41  2024     Portugal
# 42      Romania  Netherlands  Match 43  2024  Netherlands
# 43      Austria       Turkey  Match 44  2024      Austria

# %%
df_fixture_knoutout
# Out:
#            home         away     score  year       winner
# 36  Switzerland        Italy  Match 38  2024        Italy
# 37      Germany      Denmark  Match 37  2024      Germany
# 38      England     Slovakia  Match 40  2024      England
# 39        Spain      Georgia  Match 39  2024        Spain
# 40       France      Belgium  Match 42  2024       France
# 41     Portugal     Slovenia  Match 41  2024     Portugal
# 42      Romania  Netherlands  Match 43  2024  Netherlands
# 43      Austria       Turkey  Match 44  2024      Austria

# %%
df_fixture_quarter
# Out:
#                home             away     score  year
# 44  Winner Match 39  Winner Match 37  Match 45  2024
# 45  Winner Match 41  Winner Match 42  Match 46  2024
# 46  Winner Match 40  Winner Match 38  Match 48  2024
# 47  Winner Match 43  Winner Match 44  Match 47  2024

# %%
def update_table(df_fixture_round_1, df_fixture_round_2):
    for index, row in df_fixture_round_1.iterrows():
        winner = df_fixture_round_1.loc[index, 'winner']
        match = df_fixture_round_1.loc[index, 'score']
        print(winner)
        print(match)
        df_fixture_round_2.replace({f'Winner {match}':winner}, inplace=True)
    df_fixture_round_2['winner'] = '?'

    return df_fixture_round_2

# %%
update_table(df_fixture_knoutout, df_fixture_quarter)
# Out:
# Italy
# Match 38
# Germany
# Match 37
# England
# Match 40
# Spain
# Match 39
# France
# Match 42
# Portugal
# Match 41
# Netherlands
# Match 43
# Austria
# Match 44
#            home     away     score  year winner
# 44        Spain  Germany  Match 45  2024      ?
# 45     Portugal   France  Match 46  2024      ?
# 46      England    Italy  Match 48  2024      ?
# 47  Netherlands  Austria  Match 47  2024      ?

# %%
get_winner(df_fixture_quarter)
# Out:
#            home     away     score  year       winner
# 44        Spain  Germany  Match 45  2024        Spain
# 45     Portugal   France  Match 46  2024     Portugal
# 46      England    Italy  Match 48  2024        Italy
# 47  Netherlands  Austria  Match 47  2024  Netherlands

# %%
update_table(df_fixture_quarter, df_fixture_semi)
# Out:
# Spain
# Match 45
# Portugal
# Match 46
# Italy
# Match 48
# Netherlands
# Match 47
#            home      away     score  year winner
# 48        Spain  Portugal  Match 49  2024      ?
# 49  Netherlands     Italy  Match 50  2024      ?

# %%
get_winner(df_fixture_semi)
# Out:
#            home      away     score  year winner
# 48        Spain  Portugal  Match 49  2024  Spain
# 49  Netherlands     Italy  Match 50  2024  Italy

# %%
update_table(df_fixture_semi, df_fixture_final)
# Out:
# Spain
# Match 49
# Italy
# Match 50
#      home   away     score  year winner
# 50  Spain  Italy  Match 51  2024      ?

# %%
get_winner(df_fixture_final)
# Out:
#      home   away     score  year winner
# 50  Spain  Italy  Match 51  2024  Spain
